# %% [markdown]
# <a href="https://colab.research.google.com/github/cmostir/Lab-2/blob/main/Copy_of_LAB2ChrisOstir0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# In my ER diagram I had 6 entities. Customer, Animal, Food, Pet Store, Transactions for a pet and transactions for pet food. I connected all of these entities by looking at what they have in common and tried to think how a pet shop is run. I designed the ER diagram this way because I felt the entities I chose were most logical. I started off by connecting the customer to the pets and how they got adopted. I next used the food entity to show that the animals were being fed and that food was being bought by customers. I showed how all of this occured in the pet store where the animals were being held. Lastly I showed the transactions for when a customer bought food and when the store sold it.

# %% [markdown]
# ![Copy of Copy of LAB 2- Chris Ostir (2).png](data:image/png;base64,...)
